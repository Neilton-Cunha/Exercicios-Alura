# %% [markdown]
# <a href="https://colab.research.google.com/github/Neilton-Cunha/Exercicios-Alura/blob/main/conceitos_iniciais_de_pandas_em_data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/ratings.csv')
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df.columns = ['UsuarioId', 'FilmeId', 'notas', 'momentos']
df.columns
# Out:
# Index(['UsuarioId', 'FilmeId', 'notas', 'momentos'], dtype='object')

# %%
df.head()
# Out:
#    UsuarioId  FilmeId  notas   momentos
# 0          1        1    4.0  964982703
# 1          1        3    4.0  964981247
# 2          1        6    4.0  964982224
# 3          1       47    5.0  964983815
# 4          1       50    5.0  964982931

# %%
unico = df['notas'].unique()
print(unico)

df['notas'].value_counts()
# Out:
# [4.  5.  3.  2.  1.  4.5 3.5 2.5 0.5 1.5]
# notas
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
df['notas'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns
sns.boxplot(df['notas'])
# Out:
# <Axes: ylabel='notas'>

# %%
media = df["notas"].mean()
mediana = df["notas"].median()
print(f"Média é {media}")
print(f"Mediana é {mediana}")
# Out:
# Média é 3.501556983616962
# Mediana é 3.5

# %%
df["notas"].describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: notas, dtype: float64
